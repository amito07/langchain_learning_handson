# %%
# !pip install langchain langchain-community wikipedia
# Out:
# Requirement already satisfied: langchain in d:\lanchain learning\myvenv\lib\site-packages (1.2.13)
# Requirement already satisfied: langchain-community in d:\lanchain learning\myvenv\lib\site-packages (0.4.1)
# Collecting wikipedia
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\lanchain learning\myvenv\lib\site-packages (from langchain) (1.2.20)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in d:\lanchain learning\myvenv\lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\lanchain learning\myvenv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (0.6.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-community) (2.4.0)
# Requirement already satisfied: beautifulsoup4 in d:\lanchain learning\myvenv\lib\site-packages (from wikipedia) (4.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\lanchain learning\myvenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\lanchain learning\myvenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\lanchain learning\myvenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\lanchain learning\myvenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\lanchain learning\myvenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\lanchain learning\myvenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\lanchain learning\myvenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in d:\lanchain learning\myvenv\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\lanchain learning\myvenv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\lanchain learning\myvenv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\lanchain learning\myvenv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\lanchain learning\myvenv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\lanchain learning\myvenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\lanchain learning\myvenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\lanchain learning\myvenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\lanchain learning\myvenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\lanchain learning\myvenv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\lanchain learning\myvenv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\lanchain learning\myvenv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\lanchain learning\myvenv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in d:\lanchain learning\myvenv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\lanchain learning\myvenv\lib\site-packages (from beautifulsoup4->wikipedia) (2.8.3)
# Requirement already satisfied: anyio in d:\lanchain learning\myvenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: httpcore==1.* in d:\lanchain learning\myvenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\lanchain learning\myvenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\lanchain learning\myvenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\lanchain learning\myvenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\lanchain learning\myvenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.retrievers import WikipediaRetriever

retriever = WikipediaRetriever(top_k_results=2, lang="en")

# %%
query = "Tell me about the new prime minister of Bangladesh?"
docs = retriever.invoke(query)

# %%
for i, doc in enumerate(docs):
    print(f"\n-- Result {i+1} --")
    print(f"Content:\n{doc.page_content}...")
# Out:
# -- Result 1 --
# Content:
# After the resignation of Sheikh Hasina in the aftermath of the July uprising, various cases of official and unofficial persecution and harassment against the journalists were reported throughout the country in the interim government of Muhammad Yunus. According to Ain o Salish Kendra, 294 attacks and harassment took place against journalists in Yunus government, 62 such incidents took place in 2025. Rights and Risks Analysis Group reported 640 journalists were targeted by the interim government, and 118 journalists accreditation of press council were stripped.
# Despite these, the government promised to support freedom of the press, while criticizing the media for its role during the revolution against Sheikh Hasina. In the 2025 World Press Freedom Index published by the Reporters Without Borders (RSF), Bangladesh was ranked at 149, up from 165 previously, outperforming regional peers like India and Pakistan.
#
#
# == Background ==
# On 5 August 2024, at around 2:25 p.m., Sheikh Hasina resigned from her position as the Prime Minister of Bangladesh and fled the country on a helicopter with her sister, Sheikh Rehana, to India, arriving in Delhi via Agartala.
# On 8 August 2024, Muhammad Yunus took power as the head of the interim government and was sworn into office. Sheikh Hasina's government had suppressed the press during its 15-year rule. There were expectations that press freedom in Bangladesh would improve under the new government.
#
#
# == History ==
#
# During the quota movement protests, mainstream media had began a campaign of villainizing the protestors.
# After the fall of the Sheikh Hasina-led Awami League government, the office of the president and general secretary of the Jatiya Press Club, National Press Club of Bangladesh, was vandalised and forcefully occupied after Abdul Hannan Masud of the quota movement demanded their resignation and banning Awami League-supporting journalists from the profession. The office of Shyamal Dutta of the Jatiya Press Club was vandalised and he was prevented from leaving Bangladesh. On 12 August 2024, A section of Jatiya Press Club's managing committee revoked the memberships of its president, Farida Yasmin, general secretary, Shyamal Dutta and managing committee member, Shahnaj Siddiqui Soma.
# A mob attacked and vandalized Chittagong Press Club. On 18 August 2024, the offices of Kaler Kantho and Radio Capital were vandalized at the East West Media Group compound. About 25 vehicles in the media compound were damaged.
